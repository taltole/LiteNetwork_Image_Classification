# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import os, sys
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import cv2
from keras.datasets import cifar10
from keras.utils import to_categorical
import json
# import SqueezeNet

from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras import layers, datasets, models, losses, optimizers, metrics, utils, callbacks
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image as tf_ppimg

# %% [markdown]
# ### Constant

# %%
IMGPATH = 'CIFAR10'
CLASSES = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
LBL = dict(zip(range(10), CLASSES))
IN_SHAPE = (32, 32, 3)

# %%
print(LBL)
# Out:
# {0: 'plane', 1: 'car', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'}

# %% [markdown]
# ### Loading CIFAR10 dataset batches

# %%
# NEEDS CIFAR FOLDER ON WORKING DIR

def load_CIFAR_batch(filename):
    """ load single batch of cifar """
    with open(filename, 'rb') as f:
        datadict = pickle.load(f, encoding='latin1')
        X = datadict['data']
        Y = datadict['labels']
#         X = X.reshape(10000,3072)
        Y = np.array(Y)
        return X, Y

def load_CIFAR10(ROOT):
    """ load all of cifar """
    xs = []
    ys = []
    for b in range(1,6):
        f = os.path.join(ROOT, f'data_batch_{b}')
        X, Y = load_CIFAR_batch(f)
        xs.append(X)
        ys.append(Y)
    Xtr = np.concatenate(xs)
    Ytr = np.concatenate(ys)
    del X, Y
    Xte, Yte = load_CIFAR_batch(os.path.join(ROOT, 'test_batch'))
    return Xtr, Ytr, Xte, Yte

def get_CIFAR10_data(num_training=45000, num_validation=5000, num_test=10000):
    # Load the raw CIFAR-10 data
    cifar10_dir = os.path.join(os.getcwd(), 'CIFAR10')
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    x_train = X_train.astype('float32')
    x_test = X_test.astype('float32')

    x_train /= 255
    x_test /= 255    

    # Subsample the data
    mask = range(num_training, int(num_training) + int(num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    return X_train, y_train, X_test, y_test, X_val, y_val

# Onehot 10 classes encoding
# y_train_onehot = utils.to_categorical(y_train, num_classes=10)
# y_val_onehot = utils.to_categorical(y_val, num_classes=10)
# y_test_onehot = utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# ### Loading Keras CIFAR10 dataset

# %%
# load train and test dataset
def load_dataset():
    # load dataset
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    # one hot encode target values
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    trainX, testX = prep_pixels(trainX, testX)
    return trainX, trainY, testX, testY
 
# scale pixels
def prep_pixels(train, test):
    # convert from integers to floats
    train_norm = train.astype('float32')
    test_norm = test.astype('float32')
    # normalize to range 0-1
    train_norm = train_norm / 255.0
    test_norm = test_norm / 255.0
    # return normalized images
    return train_norm, test_norm

# %% [markdown]
# ### Train Test Split

# %%
X_train, y_train, X_test, y_test = load_dataset()

# %%
print('Train - Test - Val: images shape:')
print(*list(zip(('x_train', 'y_train', 'x_test', 'y_test'), 
                map(lambda x: x.shape, (X_train, y_train, X_test, y_test)))), sep='\n')
# Out:
# Train - Test - Val: images shape:
# ('x_train', (50000, 32, 32, 3))
# ('y_train', (50000, 10))
# ('x_test', (10000, 32, 32, 3))
# ('y_test', (10000, 10))

# %% [markdown]
# ### Plot Train Test samples

# %%
def plot_images(images, labels):        
    # FOR CIFAR batches: 
    # inorder to view in imshow we need image of type (height, width, channel) rather than (channel, height, width)
    #     IMG = []
    #     for img in images:
    #         img_reshape = np.reshape(img,(3,32,32)) # get the first element from list
    #         IMG.append(np.transpose(img_reshape/255., (1,2,0)))
    #  plt.xlabel(CLASSES[y+x])
    fig = plt.figure(figsize=(8, 8))
    # plot image grid
    for x in range(5):
        label = labels[x].argmax()
        for y in range(1):
            ax = fig.add_subplot(5, 5, 5*y+x+1)
            plt.imshow(images[y+x])
            plt.xticks(np.array([]))
            plt.yticks(np.array([]))
            plt.xlabel(LBL[label])
    plt.show()

# %%
# Visualize CIFAR-10
print('Training images : ' + str(X_train.shape[0]) + ' images.')
plot_images(X_train[:5], y_train[:5])
print(20 * '-')
print('Testing images : ' + str(X_test.shape[0]) + ' images.')
plot_images(X_test[:5], y_test[:5])
# Out:
# Training images : 50000 images.
# --------------------
# Testing images : 10000 images.

# %% [markdown]
# ### The Model

# %%
def fire_module(x, fire_id, squeeze=16, expand=64):
    sq1x1 = "squeeze1x1"
    exp1x1 = "expand1x1"
    exp3x3 = "expand3x3"
    relu = "relu_"
    s_id = 'fire' + str(fire_id) + '/'

    channel_axis = 3

    x = layers.Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = layers.Activation('relu', name=s_id + relu + sq1x1)(x)

    left = layers.Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = layers.Activation('relu', name=s_id + relu + exp1x1)(left)

    right = layers.Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = layers.Activation('relu', name=s_id + relu + exp3x3)(right)

    x = layers.concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x

# %%
def SqueezeNet(input_shape=IN_SHAPE, classes=10):

    img_input = layers.Input(shape=input_shape)

    x = layers.Convolution2D(64, (3, 3), strides=(2, 2), padding='valid', name='conv1')(img_input)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu', name='relu_conv1')(x)
    x = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = layers.Dropout(0.2, name='drop9')(x)

    x = layers.Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu', name='relu_conv10')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2, name='drop11')(x)

    out = layers.Activation('softmax', name='loss')(x) 
    model = models.Model(img_input, out, name='squeezenet')

    return model

# %%
def compile_model(model):
    opt = optimizers.Adam(lr=0.001)#, momentum=0.9)
    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['accuracy'])
    return model

# %%
sn = SqueezeNet()
sn = compile_model(sn)
sn.summary()
len(sn.layers)
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 15, 15, 64)   1792        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 15, 15, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# relu_conv1 (Activation)         (None, 15, 15, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 7, 7, 64)     0           relu_conv1[0][0]
# __________________________________________________________________________________________________
# fire2/squeeze1x1 (Conv2D)       (None, 7, 7, 16)     1040        pool1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_squeeze1x1 (Activati (None, 7, 7, 16)     0           fire2/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand1x1 (Conv2D)        (None, 7, 7, 64)     1088        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand3x3 (Conv2D)        (None, 7, 7, 64)     9280        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand1x1 (Activatio (None, 7, 7, 64)     0           fire2/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand3x3 (Activatio (None, 7, 7, 64)     0           fire2/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire2/concat (Concatenate)      (None, 7, 7, 128)    0           fire2/relu_expand1x1[0][0]
#                                                                  fire2/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/squeeze1x1 (Conv2D)       (None, 7, 7, 16)     2064        fire2/concat[0][0]
# __________________________________________________________________________________________________
# fire3/relu_squeeze1x1 (Activati (None, 7, 7, 16)     0           fire3/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand1x1 (Conv2D)        (None, 7, 7, 64)     1088        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand3x3 (Conv2D)        (None, 7, 7, 64)     9280        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand1x1 (Activatio (None, 7, 7, 64)     0           fire3/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand3x3 (Activatio (None, 7, 7, 64)     0           fire3/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/concat (Concatenate)      (None, 7, 7, 128)    0           fire3/relu_expand1x1[0][0]
#                                                                  fire3/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 3, 3, 128)    0           fire3/concat[0][0]
# __________________________________________________________________________________________________
# fire4/squeeze1x1 (Conv2D)       (None, 3, 3, 32)     4128        pool3[0][0]
# __________________________________________________________________________________________________
# fire4/relu_squeeze1x1 (Activati (None, 3, 3, 32)     0           fire4/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand1x1 (Conv2D)        (None, 3, 3, 128)    4224        fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand3x3 (Conv2D)        (None, 3, 3, 128)    36992       fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand1x1 (Activatio (None, 3, 3, 128)    0           fire4/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand3x3 (Activatio (None, 3, 3, 128)    0           fire4/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire4/concat (Concatenate)      (None, 3, 3, 256)    0           fire4/relu_expand1x1[0][0]
#                                                                  fire4/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/squeeze1x1 (Conv2D)       (None, 3, 3, 32)     8224        fire4/concat[0][0]
# __________________________________________________________________________________________________
# fire5/relu_squeeze1x1 (Activati (None, 3, 3, 32)     0           fire5/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand1x1 (Conv2D)        (None, 3, 3, 128)    4224        fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand3x3 (Conv2D)        (None, 3, 3, 128)    36992       fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand1x1 (Activatio (None, 3, 3, 128)    0           fire5/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand3x3 (Activatio (None, 3, 3, 128)    0           fire5/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/concat (Concatenate)      (None, 3, 3, 256)    0           fire5/relu_expand1x1[0][0]
#                                                                  fire5/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# drop9 (Dropout)                 (None, 3, 3, 256)    0           fire5/concat[0][0]
# __________________________________________________________________________________________________
# conv10 (Conv2D)                 (None, 3, 3, 10)     2570        drop9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 3, 3, 10)     40          conv10[0][0]
# __________________________________________________________________________________________________
# relu_conv10 (Activation)        (None, 3, 3, 10)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 10)           0           relu_conv10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 10)           40          global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# drop11 (Dropout)                (None, 10)           0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# loss (Activation)               (None, 10)           0           drop11[0][0]
# ==================================================================================================
# Total params: 123,322
# Trainable params: 123,154
# Non-trainable params: 168
# __________________________________________________________________________________________________
# 42

# %% [markdown]
# ### Training

# %%
def run_test_harness(model, X_train, y_train, X_test, y_test):
    """
    function takes model X,Y train test arguments and create data generator for fit and evaluate.
    return summarize diagnostics.
    """
    datagen = tf_ppimg.ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
    # prepare iterator
    it_train = datagen.flow(X_train, y_train, batch_size=64)
    # fit model
    steps = int(X_train.shape[0] / 64)
    history = model.fit(it_train, steps_per_epoch=steps, epochs=400, validation_data=(X_test, y_test))
    # evaluate model
    _, acc = model.evaluate(X_test, y_test, verbose=0)
    print('> %.3f' % (acc * 100.0))

    return history

# %%
# entry point, run the test harness
history = run_test_harness(sn, X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/400
# 781/781 [==============================] - 30s 38ms/step - loss: 1.6336 - accuracy: 0.4242 - val_loss: 1.7885 - val_accuracy: 0.3946
# Epoch 2/400
# 781/781 [==============================] - 29s 37ms/step - loss: 1.4857 - accuracy: 0.4786 - val_loss: 1.5892 - val_accuracy: 0.4527
# Epoch 3/400
# 781/781 [==============================] - 29s 37ms/step - loss: 1.4005 - accuracy: 0.5073 - val_loss: 1.4946 - val_accuracy: 0.4840
# Epoch 4/400
# 781/781 [==============================] - 29s 37ms/step - loss: 1.3272 - accuracy: 0.5330 - val_loss: 1.2520 - val_accuracy: 0.5666
# Epoch 5/400
# 781/781 [==============================] - 29s 37ms/step - loss: 1.2724 - accuracy: 0.5518 - val_loss: 1.1441 - val_accuracy: 0.6050
# Epoch 6/400
# 781/781 [==============================] - 29s 37ms/step - loss: 1.2259 - accuracy: 0.5681 - val_loss: 1.1647 - val_accuracy: 0.5960
# Epoch 7/400
# 781/781 [==============================] - 29s 37ms/step - loss: 1.1900 - accuracy: 0.5806 - val_loss: 1.2686 - val_accuracy: 0.5792
# Epoch 8/400
# 781/781 [==============================] - 29s 38ms/step - loss: 1.1651 - accuracy: 0.5845 - val_loss: 1.0275 - val_accuracy: 0.6560
# Epoch 9/400
# 781/781 [==============================] - 29s 37ms/step - loss: 1.1313 - accuracy: 0.5988 - val_loss: 1.0071 - val_accuracy: 0.6550
# Epoch 10/400
# 781/781 [==============================] - 30s 38ms/step - loss: 1.1102 - accuracy: 0.6058 - val_loss: 1.0749 - val_accuracy: 0.6319
# Epoch 11/400
# 781/781 [==============================] - 28s 36ms/step - loss: 1.0946 - accuracy: 0.6126 - val_loss: 0.9651 - val_accuracy: 0.6751
# Epoch 12/400
# 781/781 [==============================] - 28s 35ms/step - loss: 1.0754 - accuracy: 0.6173 - val_loss: 1.1655 - val_accuracy: 0.6064
# Epoch 13/400
# 781/781 [==============================] - 28s 35ms/step - loss: 1.0577 - accuracy: 0.6238 - val_loss: 0.9719 - val_accuracy: 0.6726
# Epoch 14/400
# 781/781 [==============================] - 28s 36ms/step - loss: 1.0490 - accuracy: 0.6245 - val_loss: 0.8568 - val_accuracy: 0.7112
# Epoch 15/400
# 781/781 [==============================] - 28s 35ms/step - loss: 1.0276 - accuracy: 0.6336 - val_loss: 1.1384 - val_accuracy: 0.6365
# Epoch 16/400
# 781/781 [==============================] - 28s 35ms/step - loss: 1.0200 - accuracy: 0.6367 - val_loss: 0.9741 - val_accuracy: 0.6728
# Epoch 17/400
# 781/781 [==============================] - 28s 36ms/step - loss: 1.0135 - accuracy: 0.6360 - val_loss: 0.8763 - val_accuracy: 0.7022
# Epoch 18/400
# 781/781 [==============================] - 29s 36ms/step - loss: 1.0013 - accuracy: 0.6423 - val_loss: 0.9379 - val_accuracy: 0.6851
# Epoch 19/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.9963 - accuracy: 0.6434 - val_loss: 1.0511 - val_accuracy: 0.6456
# Epoch 20/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.9880 - accuracy: 0.6465 - val_loss: 0.8420 - val_accuracy: 0.7164
# Epoch 21/400
# 781/781 [==============================] - 30s 39ms/step - loss: 0.9767 - accuracy: 0.6500 - val_loss: 0.8846 - val_accuracy: 0.7022
# Epoch 22/400
# 781/781 [==============================] - 32s 41ms/step - loss: 0.9659 - accuracy: 0.6515 - val_loss: 1.0845 - val_accuracy: 0.6412
# Epoch 23/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9555 - accuracy: 0.6554 - val_loss: 0.8222 - val_accuracy: 0.7267
# Epoch 24/400
# 781/781 [==============================] - 35s 45ms/step - loss: 0.9592 - accuracy: 0.6547 - val_loss: 0.8919 - val_accuracy: 0.6978
# Epoch 25/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9442 - accuracy: 0.6591 - val_loss: 0.7779 - val_accuracy: 0.7416
# Epoch 26/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9387 - accuracy: 0.6619 - val_loss: 0.7806 - val_accuracy: 0.7367
# Epoch 27/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9355 - accuracy: 0.6644 - val_loss: 0.9651 - val_accuracy: 0.6757
# Epoch 28/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9218 - accuracy: 0.6667 - val_loss: 0.8074 - val_accuracy: 0.7288
# Epoch 29/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9246 - accuracy: 0.6636 - val_loss: 0.6967 - val_accuracy: 0.7668
# Epoch 30/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9136 - accuracy: 0.6708 - val_loss: 0.7445 - val_accuracy: 0.7468
# Epoch 31/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9094 - accuracy: 0.6706 - val_loss: 0.7907 - val_accuracy: 0.7332
# Epoch 32/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9054 - accuracy: 0.6751 - val_loss: 0.7186 - val_accuracy: 0.7558
# Epoch 33/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9081 - accuracy: 0.6720 - val_loss: 0.8848 - val_accuracy: 0.7039
# Epoch 34/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9031 - accuracy: 0.6735 - val_loss: 0.7653 - val_accuracy: 0.7390
# Epoch 35/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8924 - accuracy: 0.6764 - val_loss: 0.8252 - val_accuracy: 0.7240
# Epoch 36/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8913 - accuracy: 0.6770 - val_loss: 0.9910 - val_accuracy: 0.6790
# Epoch 37/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8861 - accuracy: 0.6789 - val_loss: 0.8301 - val_accuracy: 0.7239
# Epoch 38/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8778 - accuracy: 0.6822 - val_loss: 0.7425 - val_accuracy: 0.7488
# Epoch 39/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8780 - accuracy: 0.6809 - val_loss: 0.7764 - val_accuracy: 0.7390
# Epoch 40/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8703 - accuracy: 0.6854 - val_loss: 0.6756 - val_accuracy: 0.7713
# Epoch 41/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8723 - accuracy: 0.6805 - val_loss: 0.6795 - val_accuracy: 0.7698
# Epoch 42/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8685 - accuracy: 0.6851 - val_loss: 0.7999 - val_accuracy: 0.7354
# Epoch 43/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8643 - accuracy: 0.6902 - val_loss: 0.6714 - val_accuracy: 0.7746
# Epoch 44/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8590 - accuracy: 0.6897 - val_loss: 0.8324 - val_accuracy: 0.7244
# Epoch 45/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8576 - accuracy: 0.6872 - val_loss: 0.6794 - val_accuracy: 0.7702
# Epoch 46/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8674 - accuracy: 0.6864 - val_loss: 0.7708 - val_accuracy: 0.7386
# Epoch 47/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8483 - accuracy: 0.6885 - val_loss: 1.1666 - val_accuracy: 0.6540
# Epoch 48/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8426 - accuracy: 0.6916 - val_loss: 0.7602 - val_accuracy: 0.7440
# Epoch 49/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8448 - accuracy: 0.6931 - val_loss: 0.7118 - val_accuracy: 0.7631
# Epoch 50/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8427 - accuracy: 0.6918 - val_loss: 0.7663 - val_accuracy: 0.7453
# Epoch 51/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8433 - accuracy: 0.6923 - val_loss: 0.7019 - val_accuracy: 0.7632
# Epoch 52/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8313 - accuracy: 0.6976 - val_loss: 0.7986 - val_accuracy: 0.7426
# Epoch 53/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8308 - accuracy: 0.6976 - val_loss: 0.6625 - val_accuracy: 0.7766
# Epoch 54/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8332 - accuracy: 0.6967 - val_loss: 0.6498 - val_accuracy: 0.7869
# Epoch 55/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8261 - accuracy: 0.6980 - val_loss: 0.6577 - val_accuracy: 0.7738
# Epoch 56/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.8270 - accuracy: 0.6956 - val_loss: 0.7274 - val_accuracy: 0.7569
# Epoch 57/400
# 781/781 [==============================] - 31s 40ms/step - loss: 0.8267 - accuracy: 0.6989 - val_loss: 0.7069 - val_accuracy: 0.7662
# Epoch 58/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.8204 - accuracy: 0.6996 - val_loss: 0.8482 - val_accuracy: 0.7239
# Epoch 59/400
# 781/781 [==============================] - 30s 39ms/step - loss: 0.8206 - accuracy: 0.6999 - val_loss: 0.6842 - val_accuracy: 0.7765
# Epoch 60/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.8166 - accuracy: 0.7003 - val_loss: 0.7104 - val_accuracy: 0.7664
# Epoch 61/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.8121 - accuracy: 0.7057 - val_loss: 0.6752 - val_accuracy: 0.7732
# Epoch 62/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8187 - accuracy: 0.6993 - val_loss: 0.9211 - val_accuracy: 0.7040
# Epoch 63/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8066 - accuracy: 0.7059 - val_loss: 0.6662 - val_accuracy: 0.7819
# Epoch 64/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8049 - accuracy: 0.7060 - val_loss: 0.7732 - val_accuracy: 0.7465
# Epoch 65/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8071 - accuracy: 0.7056 - val_loss: 0.6973 - val_accuracy: 0.7650
# Epoch 66/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8074 - accuracy: 0.7038 - val_loss: 0.6450 - val_accuracy: 0.7854
# Epoch 67/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7992 - accuracy: 0.7089 - val_loss: 0.6565 - val_accuracy: 0.7843
# Epoch 68/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7912 - accuracy: 0.7084 - val_loss: 0.7484 - val_accuracy: 0.7583
# Epoch 69/400
# 781/781 [==============================] - 28s 35ms/step - loss: 0.7966 - accuracy: 0.7079 - val_loss: 0.7457 - val_accuracy: 0.7558
# Epoch 70/400
# 781/781 [==============================] - 94s 120ms/step - loss: 0.7998 - accuracy: 0.7061 - val_loss: 0.6719 - val_accuracy: 0.7787
# Epoch 71/400
# 781/781 [==============================] - 91s 116ms/step - loss: 0.7982 - accuracy: 0.7071 - val_loss: 0.6446 - val_accuracy: 0.7866
# Epoch 72/400
# 781/781 [==============================] - 195s 250ms/step - loss: 0.7974 - accuracy: 0.7072 - val_loss: 0.7915 - val_accuracy: 0.7411
# Epoch 73/400
# 781/781 [==============================] - 31s 39ms/step - loss: 0.7923 - accuracy: 0.7092 - val_loss: 0.6376 - val_accuracy: 0.7894
# Epoch 74/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7927 - accuracy: 0.7083 - val_loss: 0.7324 - val_accuracy: 0.7607
# Epoch 75/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7854 - accuracy: 0.7099 - val_loss: 0.7073 - val_accuracy: 0.7651
# Epoch 76/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7898 - accuracy: 0.7094 - val_loss: 0.6919 - val_accuracy: 0.7653
# Epoch 77/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7775 - accuracy: 0.7165 - val_loss: 0.7583 - val_accuracy: 0.7568
# Epoch 78/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7839 - accuracy: 0.7103 - val_loss: 0.7446 - val_accuracy: 0.7514
# Epoch 79/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7830 - accuracy: 0.7135 - val_loss: 0.7689 - val_accuracy: 0.7433
# Epoch 80/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7773 - accuracy: 0.7140 - val_loss: 0.6774 - val_accuracy: 0.7841
# Epoch 81/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7887 - accuracy: 0.7088 - val_loss: 0.6217 - val_accuracy: 0.7937
# Epoch 82/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7737 - accuracy: 0.7145 - val_loss: 0.5950 - val_accuracy: 0.8000
# Epoch 83/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7838 - accuracy: 0.7095 - val_loss: 0.7052 - val_accuracy: 0.7675
# Epoch 84/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7705 - accuracy: 0.7166 - val_loss: 0.6515 - val_accuracy: 0.7815
# Epoch 85/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7719 - accuracy: 0.7162 - val_loss: 0.5738 - val_accuracy: 0.8138
# Epoch 86/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7749 - accuracy: 0.7133 - val_loss: 0.6389 - val_accuracy: 0.7888
# Epoch 87/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7731 - accuracy: 0.7145 - val_loss: 0.6705 - val_accuracy: 0.7769
# Epoch 88/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7658 - accuracy: 0.7167 - val_loss: 0.6273 - val_accuracy: 0.7966
# Epoch 89/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7642 - accuracy: 0.7190 - val_loss: 0.6502 - val_accuracy: 0.7881
# Epoch 90/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7634 - accuracy: 0.7182 - val_loss: 0.6653 - val_accuracy: 0.7752
# Epoch 91/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7646 - accuracy: 0.7180 - val_loss: 0.6873 - val_accuracy: 0.7725
# Epoch 92/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7592 - accuracy: 0.7212 - val_loss: 0.6198 - val_accuracy: 0.7978
# Epoch 93/400
# 781/781 [==============================] - 29s 36ms/step - loss: 0.7612 - accuracy: 0.7182 - val_loss: 0.7699 - val_accuracy: 0.7498
# Epoch 94/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7553 - accuracy: 0.7215 - val_loss: 0.7014 - val_accuracy: 0.7697
# Epoch 95/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7619 - accuracy: 0.7166 - val_loss: 0.6902 - val_accuracy: 0.7680
# Epoch 96/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7583 - accuracy: 0.7171 - val_loss: 0.6554 - val_accuracy: 0.7858
# Epoch 97/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7523 - accuracy: 0.7217 - val_loss: 0.6137 - val_accuracy: 0.7974
# Epoch 98/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7461 - accuracy: 0.7240 - val_loss: 0.5888 - val_accuracy: 0.8018
# Epoch 99/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7548 - accuracy: 0.7237 - val_loss: 0.6671 - val_accuracy: 0.7794
# Epoch 100/400
# 781/781 [==============================] - 461s 591ms/step - loss: 0.7477 - accuracy: 0.7204 - val_loss: 0.6399 - val_accuracy: 0.7855
# Epoch 101/400
# 781/781 [==============================] - 142s 181ms/step - loss: 0.7425 - accuracy: 0.7247 - val_loss: 0.6177 - val_accuracy: 0.7954
# Epoch 102/400
# 781/781 [==============================] - 604s 775ms/step - loss: 0.7442 - accuracy: 0.7246 - val_loss: 0.7201 - val_accuracy: 0.7652
# Epoch 103/400
# 781/781 [==============================] - 33s 43ms/step - loss: 0.7475 - accuracy: 0.7225 - val_loss: 0.7282 - val_accuracy: 0.7609
# Epoch 104/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7435 - accuracy: 0.7249 - val_loss: 0.6708 - val_accuracy: 0.7784
# Epoch 105/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.7378 - accuracy: 0.7253 - val_loss: 0.6828 - val_accuracy: 0.7787
# Epoch 106/400
# 781/781 [==============================] - 28s 35ms/step - loss: 0.7431 - accuracy: 0.7228 - val_loss: 0.6539 - val_accuracy: 0.7866
# Epoch 107/400
# 781/781 [==============================] - 1888s 2s/step - loss: 0.7373 - accuracy: 0.7258 - val_loss: 0.6983 - val_accuracy: 0.7697
# Epoch 108/400
# 781/781 [==============================] - 60s 76ms/step - loss: 0.7464 - accuracy: 0.7252 - val_loss: 0.6928 - val_accuracy: 0.7711
# Epoch 109/400
# 781/781 [==============================] - 37s 47ms/step - loss: 0.7406 - accuracy: 0.7246 - val_loss: 0.6172 - val_accuracy: 0.7945
# Epoch 110/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.7366 - accuracy: 0.7271 - val_loss: 0.6672 - val_accuracy: 0.7819
# Epoch 111/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.7358 - accuracy: 0.7263 - val_loss: 0.6571 - val_accuracy: 0.7836
# Epoch 112/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7285 - accuracy: 0.7303 - val_loss: 0.7937 - val_accuracy: 0.7370
# Epoch 113/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7363 - accuracy: 0.7275 - val_loss: 0.5801 - val_accuracy: 0.8084
# Epoch 114/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7268 - accuracy: 0.7296 - val_loss: 0.6011 - val_accuracy: 0.8030
# Epoch 115/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7352 - accuracy: 0.7253 - val_loss: 0.6388 - val_accuracy: 0.7832
# Epoch 116/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7313 - accuracy: 0.7271 - val_loss: 0.6085 - val_accuracy: 0.7951
# Epoch 117/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7282 - accuracy: 0.7282 - val_loss: 0.7341 - val_accuracy: 0.7649
# Epoch 118/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7255 - accuracy: 0.7293 - val_loss: 0.6452 - val_accuracy: 0.7875
# Epoch 119/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7213 - accuracy: 0.7307 - val_loss: 0.6289 - val_accuracy: 0.7900
# Epoch 120/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7266 - accuracy: 0.7306 - val_loss: 0.6011 - val_accuracy: 0.8048
# Epoch 121/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7159 - accuracy: 0.7344 - val_loss: 0.5983 - val_accuracy: 0.8020
# Epoch 122/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7201 - accuracy: 0.7320 - val_loss: 0.6797 - val_accuracy: 0.7771
# Epoch 123/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7231 - accuracy: 0.7309 - val_loss: 0.6484 - val_accuracy: 0.7914
# Epoch 124/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7222 - accuracy: 0.7296 - val_loss: 0.5876 - val_accuracy: 0.8074
# Epoch 125/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.7206 - accuracy: 0.7323 - val_loss: 0.6794 - val_accuracy: 0.7835
# Epoch 126/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7201 - accuracy: 0.7313 - val_loss: 0.6239 - val_accuracy: 0.7971
# Epoch 127/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7230 - accuracy: 0.7306 - val_loss: 0.6065 - val_accuracy: 0.7997
# Epoch 128/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7174 - accuracy: 0.7318 - val_loss: 0.6302 - val_accuracy: 0.7942
# Epoch 129/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7162 - accuracy: 0.7324 - val_loss: 0.6127 - val_accuracy: 0.8029
# Epoch 130/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7184 - accuracy: 0.7334 - val_loss: 0.9334 - val_accuracy: 0.7097
# Epoch 131/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7095 - accuracy: 0.7363 - val_loss: 0.7017 - val_accuracy: 0.7754
# Epoch 132/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7138 - accuracy: 0.7321 - val_loss: 0.6336 - val_accuracy: 0.7921
# Epoch 133/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7062 - accuracy: 0.7363 - val_loss: 0.6261 - val_accuracy: 0.7961
# Epoch 134/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7130 - accuracy: 0.7349 - val_loss: 0.6170 - val_accuracy: 0.8010
# Epoch 135/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7113 - accuracy: 0.7324 - val_loss: 0.6254 - val_accuracy: 0.7921
# Epoch 136/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7080 - accuracy: 0.7371 - val_loss: 0.5851 - val_accuracy: 0.8068
# Epoch 137/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7130 - accuracy: 0.7330 - val_loss: 0.6318 - val_accuracy: 0.7933
# Epoch 138/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7024 - accuracy: 0.7385 - val_loss: 0.6895 - val_accuracy: 0.7820
# Epoch 139/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.7039 - accuracy: 0.7375 - val_loss: 0.6857 - val_accuracy: 0.7708
# Epoch 140/400
# 781/781 [==============================] - 30s 39ms/step - loss: 0.7064 - accuracy: 0.7367 - val_loss: 0.6391 - val_accuracy: 0.7885
# Epoch 141/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.6990 - accuracy: 0.7369 - val_loss: 0.8252 - val_accuracy: 0.7352
# Epoch 142/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7029 - accuracy: 0.7367 - val_loss: 0.6057 - val_accuracy: 0.8026
# Epoch 143/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7066 - accuracy: 0.7357 - val_loss: 0.6642 - val_accuracy: 0.7822
# Epoch 144/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6975 - accuracy: 0.7366 - val_loss: 0.6474 - val_accuracy: 0.7925
# Epoch 145/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6967 - accuracy: 0.7389 - val_loss: 0.5694 - val_accuracy: 0.8089
# Epoch 146/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6976 - accuracy: 0.7358 - val_loss: 0.6057 - val_accuracy: 0.7998
# Epoch 147/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6917 - accuracy: 0.7422 - val_loss: 0.6871 - val_accuracy: 0.7788
# Epoch 148/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6928 - accuracy: 0.7409 - val_loss: 0.6768 - val_accuracy: 0.7921
# Epoch 149/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6921 - accuracy: 0.7384 - val_loss: 0.6122 - val_accuracy: 0.8045
# Epoch 150/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6944 - accuracy: 0.7388 - val_loss: 0.6163 - val_accuracy: 0.7983
# Epoch 151/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.6972 - accuracy: 0.7374 - val_loss: 0.6164 - val_accuracy: 0.7998
# Epoch 152/400
# 781/781 [==============================] - 28s 35ms/step - loss: 0.6910 - accuracy: 0.7387 - val_loss: 0.5601 - val_accuracy: 0.8146
# Epoch 153/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6971 - accuracy: 0.7359 - val_loss: 0.6035 - val_accuracy: 0.8050
# Epoch 154/400
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6908 - accuracy: 0.7412 - val_loss: 0.5926 - val_accuracy: 0.8040
# Epoch 155/400
# 781/781 [==============================] - 28s 35ms/step - loss: 0.6896 - accuracy: 0.7394 - val_loss: 0.6223 - val_accuracy: 0.7961
# Epoch 156/400
# 781/781 [==============================] - 1849s 2s/step - loss: 0.6831 - accuracy: 0.7443 - val_loss: 0.6516 - val_accuracy: 0.7915
# Epoch 157/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6906 - accuracy: 0.7424 - val_loss: 0.6529 - val_accuracy: 0.7928
# Epoch 158/400
# 781/781 [==============================] - 65s 83ms/step - loss: 0.6827 - accuracy: 0.7414 - val_loss: 0.6298 - val_accuracy: 0.7982
# Epoch 159/400
# 781/781 [==============================] - 63s 80ms/step - loss: 0.6856 - accuracy: 0.7412 - val_loss: 0.6233 - val_accuracy: 0.7938
# Epoch 160/400
# 781/781 [==============================] - 61s 78ms/step - loss: 0.6889 - accuracy: 0.7393 - val_loss: 0.5451 - val_accuracy: 0.8226
# Epoch 161/400
# 781/781 [==============================] - 59s 75ms/step - loss: 0.6880 - accuracy: 0.7401 - val_loss: 0.6032 - val_accuracy: 0.8059
# Epoch 162/400
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6816 - accuracy: 0.7426 - val_loss: 0.6520 - val_accuracy: 0.7886
# Epoch 163/400
# 781/781 [==============================] - 58s 74ms/step - loss: 0.6848 - accuracy: 0.7405 - val_loss: 0.6539 - val_accuracy: 0.7935
# Epoch 164/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6828 - accuracy: 0.7402 - val_loss: 0.5886 - val_accuracy: 0.8071
# Epoch 165/400
# 781/781 [==============================] - 50s 65ms/step - loss: 0.6737 - accuracy: 0.7459 - val_loss: 0.6366 - val_accuracy: 0.7953
# Epoch 166/400
# 781/781 [==============================] - 50s 65ms/step - loss: 0.6794 - accuracy: 0.7449 - val_loss: 0.5665 - val_accuracy: 0.8158
# Epoch 167/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6799 - accuracy: 0.7438 - val_loss: 0.7194 - val_accuracy: 0.7720
# Epoch 168/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6797 - accuracy: 0.7452 - val_loss: 0.6730 - val_accuracy: 0.7825
# Epoch 169/400
# 781/781 [==============================] - 53s 67ms/step - loss: 0.6769 - accuracy: 0.7438 - val_loss: 0.5724 - val_accuracy: 0.8126
# Epoch 170/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6718 - accuracy: 0.7454 - val_loss: 0.6076 - val_accuracy: 0.8041
# Epoch 171/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6798 - accuracy: 0.7449 - val_loss: 0.5672 - val_accuracy: 0.8123
# Epoch 172/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6755 - accuracy: 0.7456 - val_loss: 0.6307 - val_accuracy: 0.7966
# Epoch 173/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6743 - accuracy: 0.7433 - val_loss: 0.6886 - val_accuracy: 0.7848
# Epoch 174/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6798 - accuracy: 0.7425 - val_loss: 0.6039 - val_accuracy: 0.8023
# Epoch 175/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6714 - accuracy: 0.7464 - val_loss: 0.6161 - val_accuracy: 0.8027
# Epoch 176/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6734 - accuracy: 0.7441 - val_loss: 0.6403 - val_accuracy: 0.7986
# Epoch 177/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6706 - accuracy: 0.7484 - val_loss: 0.5812 - val_accuracy: 0.8114
# Epoch 178/400
# 781/781 [==============================] - 54s 69ms/step - loss: 0.6740 - accuracy: 0.7451 - val_loss: 0.5834 - val_accuracy: 0.8124
# Epoch 179/400
# 781/781 [==============================] - 62s 79ms/step - loss: 0.6736 - accuracy: 0.7470 - val_loss: 0.5814 - val_accuracy: 0.8108
# Epoch 180/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6706 - accuracy: 0.7459 - val_loss: 0.5839 - val_accuracy: 0.8097
# Epoch 181/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6708 - accuracy: 0.7453 - val_loss: 0.6282 - val_accuracy: 0.7971
# Epoch 182/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6705 - accuracy: 0.7448 - val_loss: 0.7125 - val_accuracy: 0.7716
# Epoch 183/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6735 - accuracy: 0.7431 - val_loss: 0.5864 - val_accuracy: 0.8085
# Epoch 184/400
# 781/781 [==============================] - 60s 76ms/step - loss: 0.6703 - accuracy: 0.7450 - val_loss: 0.6005 - val_accuracy: 0.8063
# Epoch 185/400
# 781/781 [==============================] - 62s 79ms/step - loss: 0.6620 - accuracy: 0.7485 - val_loss: 0.8151 - val_accuracy: 0.7594
# Epoch 186/400
# 781/781 [==============================] - 63s 80ms/step - loss: 0.6644 - accuracy: 0.7481 - val_loss: 0.6148 - val_accuracy: 0.8009
# Epoch 187/400
# 781/781 [==============================] - 61s 78ms/step - loss: 0.6575 - accuracy: 0.7510 - val_loss: 0.7025 - val_accuracy: 0.7799
# Epoch 188/400
# 781/781 [==============================] - 61s 78ms/step - loss: 0.6598 - accuracy: 0.7504 - val_loss: 0.6405 - val_accuracy: 0.7909
# Epoch 189/400
# 781/781 [==============================] - 64s 82ms/step - loss: 0.6622 - accuracy: 0.7487 - val_loss: 0.6044 - val_accuracy: 0.8055
# Epoch 190/400
# 781/781 [==============================] - 66s 84ms/step - loss: 0.6635 - accuracy: 0.7485 - val_loss: 0.6542 - val_accuracy: 0.7886
# Epoch 191/400
# 781/781 [==============================] - 143s 183ms/step - loss: 0.6607 - accuracy: 0.7474 - val_loss: 0.5958 - val_accuracy: 0.8078
# Epoch 192/400
# 781/781 [==============================] - 80s 102ms/step - loss: 0.6594 - accuracy: 0.7485 - val_loss: 0.5963 - val_accuracy: 0.8057
# Epoch 193/400
# 781/781 [==============================] - 192s 245ms/step - loss: 0.6604 - accuracy: 0.7487 - val_loss: 0.6519 - val_accuracy: 0.7986
# Epoch 194/400
# 781/781 [==============================] - 138s 176ms/step - loss: 0.6587 - accuracy: 0.7471 - val_loss: 0.6703 - val_accuracy: 0.7925
# Epoch 195/400
# 781/781 [==============================] - 119s 153ms/step - loss: 0.6527 - accuracy: 0.7521 - val_loss: 0.8349 - val_accuracy: 0.7527
# Epoch 196/400
# 781/781 [==============================] - 135s 173ms/step - loss: 0.6587 - accuracy: 0.7486 - val_loss: 0.5912 - val_accuracy: 0.8055
# Epoch 197/400
# 781/781 [==============================] - 132s 169ms/step - loss: 0.6635 - accuracy: 0.7469 - val_loss: 0.5900 - val_accuracy: 0.8106
# Epoch 198/400
# 781/781 [==============================] - 147s 188ms/step - loss: 0.6541 - accuracy: 0.7517 - val_loss: 0.6397 - val_accuracy: 0.7943
# Epoch 199/400
# 781/781 [==============================] - 159s 203ms/step - loss: 0.6619 - accuracy: 0.7488 - val_loss: 0.7206 - val_accuracy: 0.7705
# Epoch 200/400
# 781/781 [==============================] - 147s 187ms/step - loss: 0.6604 - accuracy: 0.7492 - val_loss: 0.5745 - val_accuracy: 0.8094
# Epoch 201/400
# 781/781 [==============================] - 151s 193ms/step - loss: 0.6574 - accuracy: 0.7494 - val_loss: 0.5696 - val_accuracy: 0.8160
# Epoch 202/400
# 781/781 [==============================] - 154s 197ms/step - loss: 0.6548 - accuracy: 0.7499 - val_loss: 0.6172 - val_accuracy: 0.8046
# Epoch 203/400
# 781/781 [==============================] - 228s 292ms/step - loss: 0.6508 - accuracy: 0.7508 - val_loss: 0.7070 - val_accuracy: 0.7790
# Epoch 204/400
# 781/781 [==============================] - 143s 183ms/step - loss: 0.6621 - accuracy: 0.7495 - val_loss: 0.6030 - val_accuracy: 0.8043
# Epoch 205/400
# 781/781 [==============================] - 176s 226ms/step - loss: 0.6601 - accuracy: 0.7498 - val_loss: 0.7102 - val_accuracy: 0.7813
# Epoch 206/400
# 781/781 [==============================] - 146s 187ms/step - loss: 0.6532 - accuracy: 0.7534 - val_loss: 0.5793 - val_accuracy: 0.8103
# Epoch 207/400
# 781/781 [==============================] - 163s 209ms/step - loss: 0.6528 - accuracy: 0.7523 - val_loss: 0.6631 - val_accuracy: 0.7894
# Epoch 208/400
# 781/781 [==============================] - 174s 223ms/step - loss: 0.6486 - accuracy: 0.7513 - val_loss: 0.6495 - val_accuracy: 0.7894
# Epoch 209/400
# 781/781 [==============================] - 151s 193ms/step - loss: 0.6531 - accuracy: 0.7504 - val_loss: 0.6900 - val_accuracy: 0.7847
# Epoch 210/400
# 781/781 [==============================] - 144s 185ms/step - loss: 0.6528 - accuracy: 0.7509 - val_loss: 0.6429 - val_accuracy: 0.7971
# Epoch 211/400
# 781/781 [==============================] - 148s 189ms/step - loss: 0.6496 - accuracy: 0.7540 - val_loss: 0.6293 - val_accuracy: 0.7980
# Epoch 212/400
# 781/781 [==============================] - 166s 212ms/step - loss: 0.6554 - accuracy: 0.7500 - val_loss: 0.5618 - val_accuracy: 0.8221
# Epoch 213/400
# 781/781 [==============================] - 151s 193ms/step - loss: 0.6515 - accuracy: 0.7521 - val_loss: 0.6596 - val_accuracy: 0.7859
# Epoch 214/400
# 781/781 [==============================] - 220s 281ms/step - loss: 0.6549 - accuracy: 0.7518 - val_loss: 0.5601 - val_accuracy: 0.8186
# Epoch 215/400
# 781/781 [==============================] - 76s 97ms/step - loss: 0.6443 - accuracy: 0.7550 - val_loss: 0.7627 - val_accuracy: 0.7740
# Epoch 216/400
# 781/781 [==============================] - 31s 40ms/step - loss: 0.6487 - accuracy: 0.7523 - val_loss: 0.5495 - val_accuracy: 0.8220
# Epoch 217/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.6478 - accuracy: 0.7511 - val_loss: 0.6516 - val_accuracy: 0.7874
# Epoch 218/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6443 - accuracy: 0.7536 - val_loss: 0.6626 - val_accuracy: 0.7915
# Epoch 219/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.6462 - accuracy: 0.7542 - val_loss: 0.6403 - val_accuracy: 0.7931
# Epoch 220/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6457 - accuracy: 0.7547 - val_loss: 0.6491 - val_accuracy: 0.7944
# Epoch 221/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6508 - accuracy: 0.7528 - val_loss: 0.6743 - val_accuracy: 0.7907
# Epoch 222/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6404 - accuracy: 0.7543 - val_loss: 0.5797 - val_accuracy: 0.8150
# Epoch 223/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.6421 - accuracy: 0.7545 - val_loss: 0.6485 - val_accuracy: 0.7914
# Epoch 224/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6425 - accuracy: 0.7544 - val_loss: 0.6095 - val_accuracy: 0.8042
# Epoch 225/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6355 - accuracy: 0.7574 - val_loss: 0.7013 - val_accuracy: 0.7802
# Epoch 226/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6403 - accuracy: 0.7554 - val_loss: 0.6665 - val_accuracy: 0.7936
# Epoch 227/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6387 - accuracy: 0.7555 - val_loss: 0.7345 - val_accuracy: 0.7749
# Epoch 228/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6482 - accuracy: 0.7536 - val_loss: 0.5975 - val_accuracy: 0.8075
# Epoch 229/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6431 - accuracy: 0.7535 - val_loss: 0.6230 - val_accuracy: 0.8030
# Epoch 230/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6426 - accuracy: 0.7533 - val_loss: 0.6192 - val_accuracy: 0.8017
# Epoch 231/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6417 - accuracy: 0.7564 - val_loss: 0.6350 - val_accuracy: 0.7932
# Epoch 232/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6368 - accuracy: 0.7574 - val_loss: 0.7273 - val_accuracy: 0.7764
# Epoch 233/400
# 781/781 [==============================] - 29s 38ms/step - loss: 0.6397 - accuracy: 0.7537 - val_loss: 0.6076 - val_accuracy: 0.8037
# Epoch 234/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6414 - accuracy: 0.7544 - val_loss: 0.5877 - val_accuracy: 0.8160
# Epoch 235/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6450 - accuracy: 0.7548 - val_loss: 0.6751 - val_accuracy: 0.7842
# Epoch 236/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6363 - accuracy: 0.7554 - val_loss: 0.5558 - val_accuracy: 0.8194
# Epoch 237/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6384 - accuracy: 0.7593 - val_loss: 0.6190 - val_accuracy: 0.8006
# Epoch 238/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6427 - accuracy: 0.7549 - val_loss: 0.6577 - val_accuracy: 0.7936
# Epoch 239/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6288 - accuracy: 0.7586 - val_loss: 0.6497 - val_accuracy: 0.7932
# Epoch 240/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6414 - accuracy: 0.7535 - val_loss: 0.6200 - val_accuracy: 0.7978
# Epoch 241/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6352 - accuracy: 0.7567 - val_loss: 0.6169 - val_accuracy: 0.8008
# Epoch 242/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6373 - accuracy: 0.7566 - val_loss: 0.6699 - val_accuracy: 0.7922
# Epoch 243/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6343 - accuracy: 0.7563 - val_loss: 0.6187 - val_accuracy: 0.8022
# Epoch 244/400
# 781/781 [==============================] - 29s 37ms/step - loss: 0.6268 - accuracy: 0.7594 - val_loss: 0.5468 - val_accuracy: 0.8235
# Epoch 245/400
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6347 - accuracy: 0.7542 - val_loss: 0.6904 - val_accuracy: 0.7862
# Epoch 246/400
# 781/781 [==============================] - 47s 60ms/step - loss: 0.6426 - accuracy: 0.7533 - val_loss: 0.5670 - val_accuracy: 0.8166
# Epoch 247/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.6321 - accuracy: 0.7586 - val_loss: 0.6131 - val_accuracy: 0.8045
# Epoch 248/400
# 781/781 [==============================] - 30s 38ms/step - loss: 0.6287 - accuracy: 0.7600 - val_loss: 0.5652 - val_accuracy: 0.8178
# Epoch 249/400
# 781/781 [==============================] - 92s 118ms/step - loss: 0.6322 - accuracy: 0.7560 - val_loss: 0.6342 - val_accuracy: 0.7978
# Epoch 250/400
# 781/781 [==============================] - 1783s 2s/step - loss: 0.6263 - accuracy: 0.7587 - val_loss: 0.6040 - val_accuracy: 0.8095
# Epoch 251/400
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6344 - accuracy: 0.7565 - val_loss: 0.6113 - val_accuracy: 0.8028
# Epoch 252/400
# 781/781 [==============================] - 57s 73ms/step - loss: 0.6324 - accuracy: 0.7563 - val_loss: 0.7266 - val_accuracy: 0.7747
# Epoch 253/400
# 781/781 [==============================] - 58s 74ms/step - loss: 0.6350 - accuracy: 0.7590 - val_loss: 0.6730 - val_accuracy: 0.7866
# Epoch 254/400
# 781/781 [==============================] - 56s 71ms/step - loss: 0.6291 - accuracy: 0.7601 - val_loss: 0.7057 - val_accuracy: 0.7894
# Epoch 255/400
# 781/781 [==============================] - 54s 69ms/step - loss: 0.6196 - accuracy: 0.7607 - val_loss: 0.7001 - val_accuracy: 0.7817
# Epoch 256/400
# 781/781 [==============================] - 55s 70ms/step - loss: 0.6238 - accuracy: 0.7580 - val_loss: 0.6793 - val_accuracy: 0.7852
# Epoch 257/400
# 781/781 [==============================] - 54s 69ms/step - loss: 0.6285 - accuracy: 0.7603 - val_loss: 0.7300 - val_accuracy: 0.7678
# Epoch 258/400
# 781/781 [==============================] - 50s 63ms/step - loss: 0.6284 - accuracy: 0.7599 - val_loss: 0.5831 - val_accuracy: 0.8205
# Epoch 259/400
# 781/781 [==============================] - 49s 62ms/step - loss: 0.6294 - accuracy: 0.7602 - val_loss: 0.7144 - val_accuracy: 0.7757
# Epoch 260/400
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6283 - accuracy: 0.7602 - val_loss: 0.6210 - val_accuracy: 0.8077
# Epoch 261/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6268 - accuracy: 0.7569 - val_loss: 0.6443 - val_accuracy: 0.7937
# Epoch 262/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6237 - accuracy: 0.7607 - val_loss: 0.5880 - val_accuracy: 0.8110
# Epoch 263/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6345 - accuracy: 0.7553 - val_loss: 0.6081 - val_accuracy: 0.8062
# Epoch 264/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6210 - accuracy: 0.7602 - val_loss: 0.6207 - val_accuracy: 0.8018
# Epoch 265/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6271 - accuracy: 0.7555 - val_loss: 0.5851 - val_accuracy: 0.8111
# Epoch 266/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6245 - accuracy: 0.7596 - val_loss: 0.5919 - val_accuracy: 0.8140
# Epoch 267/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6213 - accuracy: 0.7603 - val_loss: 0.7356 - val_accuracy: 0.7801
# Epoch 268/400
# 781/781 [==============================] - 50s 65ms/step - loss: 0.6289 - accuracy: 0.7599 - val_loss: 0.5632 - val_accuracy: 0.8179
# Epoch 269/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6273 - accuracy: 0.7584 - val_loss: 0.5558 - val_accuracy: 0.8205
# Epoch 270/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6160 - accuracy: 0.7621 - val_loss: 0.6753 - val_accuracy: 0.7871
# Epoch 271/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6239 - accuracy: 0.7598 - val_loss: 0.5990 - val_accuracy: 0.8043
# Epoch 272/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6228 - accuracy: 0.7600 - val_loss: 0.5964 - val_accuracy: 0.8116
# Epoch 273/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6252 - accuracy: 0.7618 - val_loss: 0.6008 - val_accuracy: 0.8114
# Epoch 274/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6131 - accuracy: 0.7637 - val_loss: 0.5728 - val_accuracy: 0.8118
# Epoch 275/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6197 - accuracy: 0.7611 - val_loss: 0.6120 - val_accuracy: 0.8048
# Epoch 276/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6226 - accuracy: 0.7598 - val_loss: 0.6319 - val_accuracy: 0.7963
# Epoch 277/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6224 - accuracy: 0.7608 - val_loss: 0.6411 - val_accuracy: 0.7975
# Epoch 278/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6169 - accuracy: 0.7632 - val_loss: 0.6767 - val_accuracy: 0.7955
# Epoch 279/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6191 - accuracy: 0.7598 - val_loss: 0.6182 - val_accuracy: 0.8077
# Epoch 280/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6194 - accuracy: 0.7608 - val_loss: 0.5964 - val_accuracy: 0.8114
# Epoch 281/400
# 781/781 [==============================] - 50s 64ms/step - loss: 0.6096 - accuracy: 0.7640 - val_loss: 0.5426 - val_accuracy: 0.8261
# Epoch 282/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6189 - accuracy: 0.7636 - val_loss: 0.6580 - val_accuracy: 0.7901
# Epoch 283/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6175 - accuracy: 0.7619 - val_loss: 0.6312 - val_accuracy: 0.8021
# Epoch 284/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6153 - accuracy: 0.7606 - val_loss: 0.7217 - val_accuracy: 0.7798
# Epoch 285/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6143 - accuracy: 0.7647 - val_loss: 0.5630 - val_accuracy: 0.8185
# Epoch 286/400
# 781/781 [==============================] - 51s 65ms/step - loss: 0.6094 - accuracy: 0.7652 - val_loss: 0.6255 - val_accuracy: 0.8045
# Epoch 287/400
# 781/781 [==============================] - 52s 66ms/step - loss: 0.6168 - accuracy: 0.7626 - val_loss: 0.5916 - val_accuracy: 0.8124
# Epoch 288/400
# 781/781 [==============================] - 59s 75ms/step - loss: 0.6147 - accuracy: 0.7627 - val_loss: 0.5721 - val_accuracy: 0.8162
# Epoch 289/400
# 781/781 [==============================] - 61s 77ms/step - loss: 0.6169 - accuracy: 0.7626 - val_loss: 0.5799 - val_accuracy: 0.8179
# Epoch 290/400
# 781/781 [==============================] - 58s 74ms/step - loss: 0.6157 - accuracy: 0.7621 - val_loss: 0.6272 - val_accuracy: 0.7987
# Epoch 291/400
# 781/781 [==============================] - 58s 75ms/step - loss: 0.6179 - accuracy: 0.7627 - val_loss: 0.5977 - val_accuracy: 0.8129
# Epoch 292/400
# 781/781 [==============================] - 58s 75ms/step - loss: 0.6162 - accuracy: 0.7620 - val_loss: 0.5397 - val_accuracy: 0.8268
# Epoch 293/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6119 - accuracy: 0.7646 - val_loss: 0.6923 - val_accuracy: 0.7861
# Epoch 294/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6097 - accuracy: 0.7630 - val_loss: 0.5635 - val_accuracy: 0.8173
# Epoch 295/400
# 781/781 [==============================] - 59s 75ms/step - loss: 0.6096 - accuracy: 0.7667 - val_loss: 0.7125 - val_accuracy: 0.7837
# Epoch 296/400
# 781/781 [==============================] - 58s 74ms/step - loss: 0.6150 - accuracy: 0.7638 - val_loss: 0.5756 - val_accuracy: 0.8180
# Epoch 297/400
# 781/781 [==============================] - 58s 75ms/step - loss: 0.6085 - accuracy: 0.7670 - val_loss: 0.5780 - val_accuracy: 0.8129
# Epoch 298/400
# 781/781 [==============================] - 58s 74ms/step - loss: 0.6084 - accuracy: 0.7655 - val_loss: 0.5455 - val_accuracy: 0.8223
# Epoch 299/400
# 781/781 [==============================] - 59s 75ms/step - loss: 0.6103 - accuracy: 0.7642 - val_loss: 0.6497 - val_accuracy: 0.7977
# Epoch 300/400
# 781/781 [==============================] - 58s 74ms/step - loss: 0.6115 - accuracy: 0.7646 - val_loss: 0.6453 - val_accuracy: 0.8008
# Epoch 301/400
# 781/781 [==============================] - 58s 74ms/step - loss: 0.6086 - accuracy: 0.7644 - val_loss: 0.6102 - val_accuracy: 0.8059
# Epoch 302/400
# 781/781 [==============================] - 59s 75ms/step - loss: 0.6078 - accuracy: 0.7672 - val_loss: 0.6464 - val_accuracy: 0.7989
# Epoch 303/400
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6136 - accuracy: 0.7632 - val_loss: 0.5523 - val_accuracy: 0.8236
# Epoch 304/400
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6127 - accuracy: 0.7628 - val_loss: 0.6649 - val_accuracy: 0.7993
# Epoch 305/400
# 781/781 [==============================] - 59s 75ms/step - loss: 0.6075 - accuracy: 0.7658 - val_loss: 0.7527 - val_accuracy: 0.7743
# Epoch 306/400
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6117 - accuracy: 0.7643 - val_loss: 0.5676 - val_accuracy: 0.8223
# Epoch 307/400
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6053 - accuracy: 0.7667 - val_loss: 0.6190 - val_accuracy: 0.8032
# Epoch 308/400
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6117 - accuracy: 0.7632 - val_loss: 0.6208 - val_accuracy: 0.8047
# Epoch 309/400
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6033 - accuracy: 0.7670 - val_loss: 0.5379 - val_accuracy: 0.8255
# Epoch 310/400
# 781/781 [==============================] - 60s 76ms/step - loss: 0.6100 - accuracy: 0.7624 - val_loss: 0.6038 - val_accuracy: 0.8077
# Epoch 311/400
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6045 - accuracy: 0.7655 - val_loss: 0.5573 - val_accuracy: 0.8257
# Epoch 312/400
# 781/781 [==============================] - 60s 76ms/step - loss: 0.6114 - accuracy: 0.7641 - val_loss: 0.5773 - val_accuracy: 0.8195
# Epoch 313/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6098 - accuracy: 0.7638 - val_loss: 0.6866 - val_accuracy: 0.7876
# Epoch 314/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6044 - accuracy: 0.7671 - val_loss: 0.5960 - val_accuracy: 0.8111
# Epoch 315/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6103 - accuracy: 0.7634 - val_loss: 0.6749 - val_accuracy: 0.7867
# Epoch 316/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6072 - accuracy: 0.7645 - val_loss: 0.6003 - val_accuracy: 0.8115
# Epoch 317/400
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6042 - accuracy: 0.7653 - val_loss: 0.5832 - val_accuracy: 0.8175
# Epoch 318/400
# 781/781 [==============================] - 82s 104ms/step - loss: 0.6127 - accuracy: 0.7626 - val_loss: 0.5434 - val_accuracy: 0.8300
# Epoch 319/400
# 781/781 [==============================] - 119s 152ms/step - loss: 0.6033 - accuracy: 0.7658 - val_loss: 0.5665 - val_accuracy: 0.8209
# Epoch 320/400
# 781/781 [==============================] - 116s 149ms/step - loss: 0.6032 - accuracy: 0.7657 - val_loss: 0.5903 - val_accuracy: 0.8048
# Epoch 321/400
# 781/781 [==============================] - 121s 155ms/step - loss: 0.6037 - accuracy: 0.7670 - val_loss: 0.7481 - val_accuracy: 0.7780
# Epoch 322/400
# 781/781 [==============================] - 126s 161ms/step - loss: 0.6047 - accuracy: 0.7646 - val_loss: 0.6630 - val_accuracy: 0.7987
# Epoch 323/400
# 781/781 [==============================] - 133s 170ms/step - loss: 0.6103 - accuracy: 0.7656 - val_loss: 0.5792 - val_accuracy: 0.8133
# Epoch 324/400
# 781/781 [==============================] - 118s 151ms/step - loss: 0.6004 - accuracy: 0.7682 - val_loss: 0.5867 - val_accuracy: 0.8169
# Epoch 325/400
# 781/781 [==============================] - 113s 144ms/step - loss: 0.5981 - accuracy: 0.7673 - val_loss: 0.6041 - val_accuracy: 0.8111
# Epoch 326/400
# 781/781 [==============================] - 124s 159ms/step - loss: 0.6009 - accuracy: 0.7696 - val_loss: 0.5925 - val_accuracy: 0.8141
# Epoch 327/400
# 781/781 [==============================] - 142s 181ms/step - loss: 0.5989 - accuracy: 0.7685 - val_loss: 0.6165 - val_accuracy: 0.8123
# Epoch 328/400
# 781/781 [==============================] - 117s 150ms/step - loss: 0.5989 - accuracy: 0.7668 - val_loss: 0.5817 - val_accuracy: 0.8188
# Epoch 329/400
# 781/781 [==============================] - 142s 182ms/step - loss: 0.6017 - accuracy: 0.7659 - val_loss: 0.7571 - val_accuracy: 0.7766
# Epoch 330/400
# 781/781 [==============================] - 114s 146ms/step - loss: 0.6060 - accuracy: 0.7659 - val_loss: 0.6767 - val_accuracy: 0.7902
# Epoch 331/400
# 781/781 [==============================] - 122s 156ms/step - loss: 0.6027 - accuracy: 0.7652 - val_loss: 0.5694 - val_accuracy: 0.8210
# Epoch 332/400
# 781/781 [==============================] - 105s 133ms/step - loss: 0.6001 - accuracy: 0.7680 - val_loss: 0.6052 - val_accuracy: 0.8101
# Epoch 333/400
# 781/781 [==============================] - 120s 154ms/step - loss: 0.5995 - accuracy: 0.7684 - val_loss: 0.6406 - val_accuracy: 0.8005
# Epoch 334/400
# 781/781 [==============================] - 115s 147ms/step - loss: 0.5996 - accuracy: 0.7673 - val_loss: 0.6189 - val_accuracy: 0.8015
# Epoch 335/400
# 781/781 [==============================] - 100s 128ms/step - loss: 0.5994 - accuracy: 0.7679 - val_loss: 0.6122 - val_accuracy: 0.8065
# Epoch 336/400
# 781/781 [==============================] - 103s 131ms/step - loss: 0.5993 - accuracy: 0.7673 - val_loss: 0.6792 - val_accuracy: 0.7920
# Epoch 337/400
# 781/781 [==============================] - 102s 130ms/step - loss: 0.5947 - accuracy: 0.7688 - val_loss: 0.5289 - val_accuracy: 0.8334
# Epoch 338/400
# 781/781 [==============================] - 88s 112ms/step - loss: 0.5913 - accuracy: 0.7700 - val_loss: 0.5778 - val_accuracy: 0.8169
# Epoch 339/400
# 781/781 [==============================] - 106s 136ms/step - loss: 0.5945 - accuracy: 0.7688 - val_loss: 0.6163 - val_accuracy: 0.8057
# Epoch 340/400
# 781/781 [==============================] - 106s 136ms/step - loss: 0.5976 - accuracy: 0.7692 - val_loss: 0.6152 - val_accuracy: 0.8059
# Epoch 341/400
# 781/781 [==============================] - 134s 172ms/step - loss: 0.5973 - accuracy: 0.7683 - val_loss: 0.5433 - val_accuracy: 0.8280
# Epoch 342/400
# 781/781 [==============================] - 232s 297ms/step - loss: 0.6025 - accuracy: 0.7652 - val_loss: 0.5855 - val_accuracy: 0.8167
# Epoch 343/400
# 781/781 [==============================] - 270s 345ms/step - loss: 0.5915 - accuracy: 0.7683 - val_loss: 0.7671 - val_accuracy: 0.7770
# Epoch 344/400
# 781/781 [==============================] - 194s 249ms/step - loss: 0.5918 - accuracy: 0.7702 - val_loss: 0.5534 - val_accuracy: 0.8267
# Epoch 345/400
# 781/781 [==============================] - 221s 283ms/step - loss: 0.5911 - accuracy: 0.7707 - val_loss: 0.6268 - val_accuracy: 0.8041
# Epoch 346/400
# 781/781 [==============================] - 239s 306ms/step - loss: 0.5990 - accuracy: 0.7669 - val_loss: 0.5929 - val_accuracy: 0.8124
# Epoch 347/400
# 781/781 [==============================] - 115s 146ms/step - loss: 0.5969 - accuracy: 0.7693 - val_loss: 0.5794 - val_accuracy: 0.8154
# Epoch 348/400
# 781/781 [==============================] - 91s 117ms/step - loss: 0.5957 - accuracy: 0.7675 - val_loss: 0.5778 - val_accuracy: 0.8193
# Epoch 349/400
# 781/781 [==============================] - 91s 116ms/step - loss: 0.5919 - accuracy: 0.7707 - val_loss: 0.6480 - val_accuracy: 0.8041
# Epoch 350/400
# 781/781 [==============================] - 94s 120ms/step - loss: 0.5928 - accuracy: 0.7716 - val_loss: 0.6331 - val_accuracy: 0.8009
# Epoch 351/400
# 781/781 [==============================] - 108s 139ms/step - loss: 0.5971 - accuracy: 0.7681 - val_loss: 0.6595 - val_accuracy: 0.7927
# Epoch 352/400
# 781/781 [==============================] - 100s 129ms/step - loss: 0.5914 - accuracy: 0.7687 - val_loss: 0.7766 - val_accuracy: 0.7705
# Epoch 353/400
# 781/781 [==============================] - 93s 119ms/step - loss: 0.5928 - accuracy: 0.7718 - val_loss: 0.5616 - val_accuracy: 0.8229
# Epoch 354/400
# 781/781 [==============================] - 108s 138ms/step - loss: 0.5915 - accuracy: 0.7702 - val_loss: 0.5909 - val_accuracy: 0.8091
# Epoch 355/400
# 781/781 [==============================] - 102s 131ms/step - loss: 0.5938 - accuracy: 0.7694 - val_loss: 0.7066 - val_accuracy: 0.7860
# Epoch 356/400
# 781/781 [==============================] - 114s 146ms/step - loss: 0.5942 - accuracy: 0.7688 - val_loss: 0.5851 - val_accuracy: 0.8170
# Epoch 357/400
# 781/781 [==============================] - 101s 130ms/step - loss: 0.5953 - accuracy: 0.7709 - val_loss: 0.5982 - val_accuracy: 0.8148
# Epoch 358/400
# 781/781 [==============================] - 116s 148ms/step - loss: 0.5913 - accuracy: 0.7700 - val_loss: 0.6625 - val_accuracy: 0.7912
# Epoch 359/400
# 781/781 [==============================] - 112s 143ms/step - loss: 0.5911 - accuracy: 0.7725 - val_loss: 0.6364 - val_accuracy: 0.8068
# Epoch 360/400
# 781/781 [==============================] - 109s 140ms/step - loss: 0.5935 - accuracy: 0.7687 - val_loss: 0.6239 - val_accuracy: 0.8088
# Epoch 361/400
# 781/781 [==============================] - 119s 152ms/step - loss: 0.5907 - accuracy: 0.7725 - val_loss: 0.6257 - val_accuracy: 0.8064
# Epoch 362/400
# 781/781 [==============================] - 121s 155ms/step - loss: 0.5886 - accuracy: 0.7694 - val_loss: 0.6679 - val_accuracy: 0.7959
# Epoch 363/400
# 781/781 [==============================] - 105s 135ms/step - loss: 0.5815 - accuracy: 0.7756 - val_loss: 0.5551 - val_accuracy: 0.8244
# Epoch 364/400
# 781/781 [==============================] - 113s 144ms/step - loss: 0.5927 - accuracy: 0.7697 - val_loss: 0.5537 - val_accuracy: 0.8256
# Epoch 365/400
# 781/781 [==============================] - 110s 141ms/step - loss: 0.5836 - accuracy: 0.7732 - val_loss: 0.5967 - val_accuracy: 0.8114
# Epoch 366/400
# 781/781 [==============================] - 99s 126ms/step - loss: 0.5882 - accuracy: 0.7715 - val_loss: 0.6493 - val_accuracy: 0.7997
# Epoch 367/400
# 781/781 [==============================] - 123s 158ms/step - loss: 0.5856 - accuracy: 0.7705 - val_loss: 0.5810 - val_accuracy: 0.8194
# Epoch 368/400
# 781/781 [==============================] - 103s 132ms/step - loss: 0.5962 - accuracy: 0.7688 - val_loss: 0.6827 - val_accuracy: 0.7942
# Epoch 369/400
# 781/781 [==============================] - 122s 156ms/step - loss: 0.5864 - accuracy: 0.7719 - val_loss: 0.5809 - val_accuracy: 0.8205
# Epoch 370/400
# 781/781 [==============================] - 115s 147ms/step - loss: 0.5851 - accuracy: 0.7730 - val_loss: 0.5882 - val_accuracy: 0.8090
# Epoch 371/400
# 781/781 [==============================] - 107s 138ms/step - loss: 0.5893 - accuracy: 0.7708 - val_loss: 0.6510 - val_accuracy: 0.7983
# Epoch 372/400
# 781/781 [==============================] - 136s 174ms/step - loss: 0.5882 - accuracy: 0.7721 - val_loss: 0.6175 - val_accuracy: 0.8066
# Epoch 373/400
# 781/781 [==============================] - 101s 129ms/step - loss: 0.5923 - accuracy: 0.7690 - val_loss: 0.5994 - val_accuracy: 0.8106
# Epoch 374/400
# 781/781 [==============================] - 110s 141ms/step - loss: 0.5901 - accuracy: 0.7710 - val_loss: 0.7313 - val_accuracy: 0.7722
# Epoch 375/400
# 781/781 [==============================] - 103s 132ms/step - loss: 0.5961 - accuracy: 0.7686 - val_loss: 0.6123 - val_accuracy: 0.8099
# Epoch 376/400
# 781/781 [==============================] - 88s 113ms/step - loss: 0.5901 - accuracy: 0.7682 - val_loss: 0.6136 - val_accuracy: 0.8094
# Epoch 377/400
# 781/781 [==============================] - 96s 122ms/step - loss: 0.5833 - accuracy: 0.7725 - val_loss: 0.6291 - val_accuracy: 0.8088
# Epoch 378/400
# 781/781 [==============================] - 125s 159ms/step - loss: 0.5927 - accuracy: 0.7685 - val_loss: 0.6469 - val_accuracy: 0.8028
# Epoch 379/400
# 781/781 [==============================] - 103s 132ms/step - loss: 0.5861 - accuracy: 0.7715 - val_loss: 0.6050 - val_accuracy: 0.8120
# Epoch 380/400
# 781/781 [==============================] - 106s 136ms/step - loss: 0.5840 - accuracy: 0.7713 - val_loss: 0.5780 - val_accuracy: 0.8182
# Epoch 381/400
# 781/781 [==============================] - 117s 149ms/step - loss: 0.5818 - accuracy: 0.7714 - val_loss: 0.5682 - val_accuracy: 0.8201
# Epoch 382/400
# 781/781 [==============================] - 111s 143ms/step - loss: 0.5830 - accuracy: 0.7738 - val_loss: 0.5384 - val_accuracy: 0.8305
# Epoch 383/400
# 781/781 [==============================] - 94s 121ms/step - loss: 0.5893 - accuracy: 0.7698 - val_loss: 0.5707 - val_accuracy: 0.8175
# Epoch 384/400
# 781/781 [==============================] - 83s 107ms/step - loss: 0.5844 - accuracy: 0.7740 - val_loss: 0.6194 - val_accuracy: 0.8078
# Epoch 385/400
# 781/781 [==============================] - 98s 125ms/step - loss: 0.5854 - accuracy: 0.7713 - val_loss: 0.6395 - val_accuracy: 0.8033
# Epoch 386/400
# 781/781 [==============================] - 100s 129ms/step - loss: 0.5897 - accuracy: 0.7692 - val_loss: 0.5872 - val_accuracy: 0.8183
# Epoch 387/400
# 781/781 [==============================] - 110s 141ms/step - loss: 0.5873 - accuracy: 0.7696 - val_loss: 0.5620 - val_accuracy: 0.8232
# Epoch 388/400
# 781/781 [==============================] - 99s 126ms/step - loss: 0.5849 - accuracy: 0.7707 - val_loss: 0.5737 - val_accuracy: 0.8202
# Epoch 389/400
# 781/781 [==============================] - 98s 125ms/step - loss: 0.5785 - accuracy: 0.7727 - val_loss: 0.5908 - val_accuracy: 0.8154
# Epoch 390/400
# 781/781 [==============================] - 109s 139ms/step - loss: 0.5812 - accuracy: 0.7734 - val_loss: 0.7455 - val_accuracy: 0.7767
# Epoch 391/400
# 781/781 [==============================] - 82s 104ms/step - loss: 0.5830 - accuracy: 0.7712 - val_loss: 0.6415 - val_accuracy: 0.7991
# Epoch 392/400
# 781/781 [==============================] - 114s 147ms/step - loss: 0.5758 - accuracy: 0.7762 - val_loss: 0.7037 - val_accuracy: 0.7872
# Epoch 393/400
# 781/781 [==============================] - 104s 133ms/step - loss: 0.5809 - accuracy: 0.7738 - val_loss: 0.6139 - val_accuracy: 0.8112
# Epoch 394/400
# 781/781 [==============================] - 91s 117ms/step - loss: 0.5812 - accuracy: 0.7747 - val_loss: 0.5416 - val_accuracy: 0.8289
# Epoch 395/400
# 781/781 [==============================] - 113s 144ms/step - loss: 0.5835 - accuracy: 0.7734 - val_loss: 0.5919 - val_accuracy: 0.8104
# Epoch 396/400
# 781/781 [==============================] - 89s 114ms/step - loss: 0.5797 - accuracy: 0.7731 - val_loss: 0.6195 - val_accuracy: 0.8129
# Epoch 397/400
# 781/781 [==============================] - 88s 112ms/step - loss: 0.5816 - accuracy: 0.7745 - val_loss: 0.5864 - val_accuracy: 0.8208
# Epoch 398/400
# 781/781 [==============================] - 93s 119ms/step - loss: 0.5819 - accuracy: 0.7726 - val_loss: 0.5855 - val_accuracy: 0.8169
# Epoch 399/400
# 781/781 [==============================] - 86s 110ms/step - loss: 0.5847 - accuracy: 0.7725 - val_loss: 0.6099 - val_accuracy: 0.8109
# Epoch 400/400
# 781/781 [==============================] - 93s 119ms/step - loss: 0.5764 - accuracy: 0.7745 - val_loss: 0.5846 - val_accuracy: 0.8143
# > 81.430

# %% [markdown]
# ### save model architecture

# %%
save = input('Do you want to save last run (y/n) ?')
if save == 'y':
    model_json = sn.to_json()
    with open('squeeze_net_model.json', 'w') as f:
        f.write(model_json)

    with open('history_model.json', 'w') as f:
        json.dump(history.history, f)

    # save model's learned weights
    sn.save('model.h5', overwrite=True)
    
load = input('Do you want to load best model (y/n) ? ')
if load == 'y':
    sn = load_model(os.path.join(os.getcwd(), 'model.h5'))
    history = json.load(open(os.path.join(os.getcwd(), 'history_model.json')))
# Out:
# Do you want to save last run (y/n) ? y
# Do you want to load best model (y/n) ?  n

# %% [markdown]
# ### Model Evaluation

# %%
evaluate = sn.evaluate(X_test, y_test)
print(f'{list(zip(evaluate, sn.metrics_names))}')
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5846 - accuracy: 0.8143
# [(0.5846203565597534, 'loss'), (0.814300000667572, 'accuracy')]

# %%
def plot_accuracy_and_loss(history):
    plt.figure(1, figsize= (15, 10))
    # plot train and test accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('SqueezeNet accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    # plot train and test loss
    plt.subplot(222)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('SqueezeNet loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show();   
    # save plot to file
    filename = sys.argv[0].split('/')[-1]
    plt.savefig(filename + '_plot.png')
    plt.close()

# %%
plot_accuracy_and_loss(history)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = sn.predict(X_test)
y_pred_classes = [np.argmax(el) for el in y_pred]
preds=np.argmax(y_pred, axis=1)
tests=np.argmax(y_test, axis=1)

# %%
cr = classification_report(tests, preds)
print(f'Classification Report:\n {cr}')
cm = tf.math.confusion_matrix(labels=tests, predictions=preds, num_classes=10)
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83      1000
#            1       0.93      0.86      0.90      1000
#            2       0.78      0.76      0.77      1000
#            3       0.67      0.68      0.68      1000
#            4       0.79      0.83      0.81      1000
#            5       0.84      0.62      0.71      1000
#            6       0.78      0.90      0.84      1000
#            7       0.89      0.84      0.87      1000
#            8       0.77      0.96      0.85      1000
#            9       0.90      0.86      0.88      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
# Text(33.0, 0.5, 'True')

# %%
# {0: 'plane',
#  1: 'car',
#  2: 'bird',
#  3: 'cat',
#  4: 'deer',
#  5: 'dog',
#  6: 'frog',
#  7: 'horse',
#  8: 'ship',
#  9: 'truck'}

# %% [markdown]
# ### Inference

# %%
def predict_label(model, labels, imagepath):

    img = tf.keras.preprocessing.image.load_img(os.path.join(imagepath), target_size=(32, 32))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, 0)      # Create batch axis (32, 32, 3) => (1, 32, 32, 3)

    predictions = model.predict(img_array)[0]
    index = np.argmax(predictions)
    result = labels[int(index)]
    imge = plt.imread(imagepath)
    plt.figure(figsize=(5, 5))
    plt.imshow(imge)
    plt.title(f'prediction: {result}')
    plt.xticks([])
    plt.yticks([])
    plt.show();
    return result

# %%
path = os.path.join(os.getcwd(), 'static//uploads//4.jpg')
result = predict_label(sn, LBL, path)
